# %% [markdown]
# Import packages

# %%
# for numerical analysis
import numpy as np # linear algebra

# to store and process in a dataframe
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Visualizations, for ploting graphs
import matplotlib.pyplot as plt

# image processing
import matplotlib.image as mpimg

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# advanced ploting
import seaborn as sns

import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# Image manipulations
from PIL import Image
#from libjpeg import decode

# Timing utility
from timeit import default_timer as timer

from IPython.core.interactiveshell import InteractiveShell

# Printing out all outputs
InteractiveShell.ast_node_interactivity = 'all'

# PyTorch
import torchvision
from torchvision import transforms, datasets, models

import torch
from torch import optim, cuda
from torch.utils.data import DataLoader, sampler
from torch.autograd import Variable

import torch.nn as nn
import torch.nn.functional as F

from torch.nn import Linear, ReLU, CrossEntropyLoss, Sequential, Conv2d, MaxPool2d
from torch.nn import Module, Softmax, BatchNorm2d, Dropout

import gc

# file operations

import shutil
import os
from os import walk

# to list files
import glob

import cv2

print(os.listdir("ECG_data/"))
# Out:
# C:\Users\Brian Ashiali\anaconda3\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: '[WinError 127] The specified procedure could not be found'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# ['test', 'train']

# %%
# current working directory
os.getcwd()
# Out:
# 'C:\\Users\\Brian Ashiali\\Desktop\\Ml_class\\class_1\\FiN_project_Ml\\trial_2_final'

# %%
# no. of files

def list_files(startpath):
    
    for root, dirs, files in os.walk(startpath):
        
        level = root.replace(startpath, '').count(os.sep)
        
        indent = ' ' * 4 * (level)
        
        print('{}{}'.format(indent, os.path.basename(root)), '-', len(os.listdir(root)))
        
folder = 'ECG_data/'
list_files(folder)
# Out:
#  - 2
# test - 6
#     F - 161
#     M - 2101
#     N - 18926
#     Q - 1608
#     S - 556
#     V - 1447
# train - 6
#     F - 642
#     M - 8405
#     N - 75709
#     Q - 6431
#     S - 2223
#     V - 5789

# %%
folder = 'ECG_data/'
list_files(folder)
# Out:
#  - 2
# test - 6
#     F - 161
#     M - 2101
#     N - 18926
#     Q - 1608
#     S - 556
#     V - 1447
# train - 6
#     F - 642
#     M - 8405
#     N - 75709
#     Q - 6431
#     S - 2223
#     V - 5789

# %%
# list of files in the dataset /input/ecg-images/MITBIH_img

os.listdir('ECG_data/test/')
# Out:
# ['F', 'M', 'N', 'Q', 'S', 'V']

# %%
# Classes in the data

ECG_list = os.listdir('ECG_data/test/')

n_classes = len(ECG_list)

print(f'There are {n_classes} different classes.')
# Out:
# There are 6 different classes.

# %%
ECG_list
# Out:
# ['F', 'M', 'N', 'Q', 'S', 'V']

# %%
classes = ('S', 'V', 'Q', 'N', 'F', 'M')

# %% [markdown]
# Count Number of Files in the MITBIH_img Folder

# %%
N_imgs = os.listdir('ECG_data/test/N/')
print('Normal beats: ',len(N_imgs))

F_imgs = os.listdir('ECG_data/test/F/')
print('Fusion beats: ',len(F_imgs))

Q_imgs = os.listdir('ECG_data/test/Q/')
print('Unknown beats: ',len(Q_imgs))

V_imgs = os.listdir('ECG_data/test/V/')
print('Ventricular ectopic beats: ',len(V_imgs))

S_imgs = os.listdir('ECG_data/test/S/')
print('Supraventricular ectopic beats: ',len(S_imgs))

M_imgs = os.listdir('ECG_data/test/M/')
print('Mixed beats: ',len(M_imgs))
# Out:
# Normal beats:  18926
# Fusion beats:  161
# Unknown beats:  1608
# Ventricular ectopic beats:  1447
# Supraventricular ectopic beats:  556
# Mixed beats:  2101

# %%
#print(N_dir)
print(N_imgs[0])
# Out:
# N10007.png

# %% [markdown]
# EDA

# %%
def imshow(image):
    """Display image"""
    plt.figure(figsize=(6, 6))
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# %%
image = mpimg.imread(os.path.join('ECG_data/test/N/', N_imgs[0]))

imshow(image)

# %%
print(image.shape)
print(type(image))
# Out:
# (288, 432, 4)
# <class 'numpy.ndarray'>

# %% [markdown]
# Show Images From Each Folder

# %%
# Define a function which will plot several images

def image_shows(folder, number_of_images):
    
    n=number_of_images;
    
    folder_list = os.listdir(folder)
    
    fig, axes = plt.subplots(nrows = 1, ncols=n, figsize=(20, 10))
    
    for i in range(n):
        
        print(os.path.join(folder, folder_list[i]))
        
        image = mpimg.imread(os.path.join(folder, folder_list[i]));
        
        axes[i].imshow(image);

# %%
# Examples of N

image_shows(folder = 'ECG_data/test/N/', number_of_images = 6)
# Examples of S

image_shows(folder = 'ECG_data/test/S/', number_of_images = 6)
# Examples of Q

image_shows(folder = 'ECG_data/test/Q/', number_of_images = 6)
# Examples of M

image_shows(folder = 'ECG_data/test/M/', number_of_images = 6)
# Examples of V

image_shows(folder = 'ECG_data/test/V/', number_of_images = 6)
# Examples of F

image_shows(folder = 'ECG_data/test/F/', number_of_images = 6)
# Out:
# ECG_data/test/N/N10007.png
# ECG_data/test/N/N10010.png
# ECG_data/test/N/N10014.png
# ECG_data/test/N/N10019.png
# ECG_data/test/N/N10025.png
# ECG_data/test/N/N10034.png
# ECG_data/test/S/S100.png
# ECG_data/test/S/S1008.png
# ECG_data/test/S/S1010.png
# ECG_data/test/S/S1018.png
# ECG_data/test/S/S1021.png
# ECG_data/test/S/S1030.png
# ECG_data/test/Q/Q1.png
# ECG_data/test/Q/Q1002.png
# ECG_data/test/Q/Q1003.png
# ECG_data/test/Q/Q1009.png
# ECG_data/test/Q/Q1011.png
# ECG_data/test/Q/Q1021.png
# ECG_data/test/M/M0.png
# ECG_data/test/M/M1.png
# ECG_data/test/M/M10.png
# ECG_data/test/M/M100.png
# ECG_data/test/M/M1000.png
# ECG_data/test/M/M1001.png
# ECG_data/test/V/V1001.png
# ECG_data/test/V/V1006.png
# ECG_data/test/V/V1012.png
# ECG_data/test/V/V102.png
# ECG_data/test/V/V1023.png
# ECG_data/test/V/V1030.png
# ECG_data/test/F/F0.png
# ECG_data/test/F/F104.png
# ECG_data/test/F/F113.png
# ECG_data/test/F/F115.png
# ECG_data/test/F/F118.png
# ECG_data/test/F/F12.png

# %% [markdown]
# To see 3 channels I plot figures with cv 2 package

# %%
imgcv = cv2.imread(os.path.join('ECG_data/test/N/', N_imgs[0]))
plt.imshow(imgcv)
plt.show();

# %%
imgcv.shape
# Out:
# (288, 432, 3)

# %%
b = imgcv.copy()
# set green and red channels to 0
b[:, :, 1] = 0
b[:, :, 2] = 0


g = imgcv.copy()
# set blue and red channels to 0
g[:, :, 0] = 0
g[:, :, 2] = 0

r = imgcv.copy()
# set blue and green channels to 0
r[:, :, 0] = 0
r[:, :, 1] = 0

# %% [markdown]
# plot rgb

# %%
# plot data

fig = plt.figure(figsize=(15,15))

plot_1 = plt.subplot(131)
plot_1.imshow(r);

#plt.subplot(131).imshow(b);

plot_2 = plt.subplot(132, sharex=plot_1, sharey=plot_1)
plt.setp(plot_2.get_yticklabels(), visible=False);
plot_2.imshow(b);

plot_3 = plt.subplot(133, sharex=plot_1, sharey=plot_1)
plt.setp(plot_3.get_yticklabels(), visible=False);
plot_3.imshow(g);

plt.show();

# %%
for root, dirs, files in os.walk('ECG_data/'):
    print(root)
    #So, as the code runs, it will print the paths of all directories
    #within the '/ecg/' directory and its subdirectories.
# Out:
# ECG_data/
# ECG_data/test
# ECG_data/test\F
# ECG_data/test\M
# ECG_data/test\N
# ECG_data/test\Q
# ECG_data/test\S
# ECG_data/test\V
# ECG_data/train
# ECG_data/train\F
# ECG_data/train\M
# ECG_data/train\N
# ECG_data/train\Q
# ECG_data/train\S
# ECG_data/train\V

# %%
folder = 'ECG_data/'
list_files(folder)
# Out:
#  - 2
# test - 6
#     F - 161
#     M - 2101
#     N - 18926
#     Q - 1608
#     S - 556
#     V - 1447
# train - 6
#     F - 642
#     M - 8405
#     N - 75709
#     Q - 6431
#     S - 2223
#     V - 5789

# %%
N_imgs       = len(os.listdir('ECG_data/train/N/'))
N_train_imgs = len(os.listdir('ECG_data/train/N/'))
N_test_imgs  = len(os.listdir('ECG_data/test/N/'))
print('number of N images in the training file: ', N_imgs)
print('total number of test picts:    ', N_test_imgs)
# Out:
# number of N images in the training file:  75709
# total number of test picts:     18926

# %%
S_imgs       = len(os.listdir('ECG_data/train/S/'))
S_train_imgs = len(os.listdir('ECG_data/train/S/'))
S_test_imgs  = len(os.listdir('ECG_data/test/S/'))
print('number of S images in the training file: ', S_imgs)
print('total number of test picts:    ', S_test_imgs)
# Out:
# number of S images in the training file:  2223
# total number of test picts:     556

# %%
F_imgs       = len(os.listdir('ECG_data/train/F/'))
F_train_imgs = len(os.listdir('ECG_data/train/F/'))
F_test_imgs  = len(os.listdir('ECG_data/test/F/'))
print('number of F images in the training file: ', F_imgs)
print('total number of test picts:    ', F_test_imgs)
# Out:
# number of F images in the training file:  642
# total number of test picts:     161

# %%
V_imgs       = len(os.listdir('ECG_data/train/V/'))
V_train_imgs = len(os.listdir('ECG_data/train/V/'))
V_test_imgs  = len(os.listdir('ECG_data/test/V/'))
print('number of V images at the train file: ', V_imgs)
print('total number of test picts:    ', V_test_imgs)
# Out:
# number of V images at the train file:  5789
# total number of test picts:     1447

# %%
M_imgs       = len(os.listdir('ECG_data/train/M/'))
M_train_imgs = len(os.listdir('ECG_data/train/M/'))
M_test_imgs  = len(os.listdir('ECG_data/test/M/'))
print('number of M images in the training file: ', M_imgs)
print('total number of test picts:    ', M_test_imgs)
# Out:
# number of M images in the training file:  8405
# total number of test picts:     2101

# %%
Q_imgs       = len(os.listdir('ECG_data/train/Q/'))
Q_train_imgs = len(os.listdir('ECG_data/train/Q/'))
Q_test_imgs  = len(os.listdir('ECG_data/test/Q/'))
print('number of Q images in the train file: ', Q_imgs)
print('total number of test picts:    ', Q_test_imgs)
# Out:
# number of Q images in the train file:  6431
# total number of test picts:     1608

# %% [markdown]
# Lets load images with datasets.ImageFolder function and than read and plot
#
# Set Data Loader

# %%
TRAIN_PATH        = 'ECG_data/train/'

transform         = transforms.Compose(
                                       [transforms.Resize([120,120]),
                                        transforms.Grayscale(), 
                                        transforms.ToTensor(),
                                        transforms.Normalize((0.5), (0.5))
                                       ])
  
train_data_set    = datasets.ImageFolder(root=TRAIN_PATH, transform=transform)

batch_size=32

train_data_loader = DataLoader(train_data_set, batch_size=batch_size, shuffle=True)

# %%
TEST_PATH        = 'ECG_data/test/'
  
test_data_set    = datasets.ImageFolder(root=TEST_PATH, transform=transform)

test_data_loader = DataLoader(test_data_set, batch_size=batch_size, shuffle=True)

# %%
# Run this to test your data loader

images, labels = next(iter(train_data_loader))

# %%
print(type(images))

print(images.size())

print("")
print("Batch Size:   ",images.size()[0])
print("Channel Size: ",images.size()[1])
print("Image Height: ",images.size()[2])
print("Image Width:  ",images.size()[3])
# Out:
# <class 'torch.Tensor'>
# torch.Size([32, 1, 120, 120])
#
# Batch Size:    32
# Channel Size:  1
# Image Height:  120
# Image Width:   120

# %% [markdown]
# The batch size is 32, image size is reduced to 120*120 and we need only one channel(Gray Scale).

# %%
def imshow_tensor(image, ax=None, title=None, normalize=True):
    
    """Imshow for Tensor."""
    
    if ax is None:
        fig, ax = plt.subplots()
        
    image = image.numpy().transpose((1, 2, 0))

    if normalize:
        mean = np.array([0.5])
        std = np.array([0.5])
        image = std * image + mean
        image = np.clip(image, 0, 1)

    ax.imshow(image)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    
    ax.tick_params(axis='both', length=0)
    ax.set_xticklabels('')
    ax.set_yticklabels('')

    return ax

# %% [markdown]
# Plot one Batch of Files from Dataloader

# %%
# show images

ncol = 8;

imshow_tensor(torchvision.utils.make_grid(images,nrow = ncol));

# %%
# print labels

classes = ('N', 'Q', 'F', 'S', 'V','M')

nrow = batch_size/ncol;

for row in range(int(nrow)):
    
    print(' '.join('%5s' % classes[labels[(row*ncol)+j]] for j in range(ncol)))
# Out:
#     F     F     F     F     F     Q     F     F
#     F     F     F     F     F     S     F     S
#     F     F     F     F     F     F     F     S
#     F     M     F     S     S     Q     F     F

# %% [markdown]
# Building Convolutional Neural Networks

# %% [markdown]
# First CNN Model

# %%
# CNN Architect

class ConvNet_1(nn.Module):
    
    def __init__(self):
        
        super(ConvNet_1, self).__init__()

        self.layer_1  = nn.Conv2d(in_channels=1, out_channels=4, kernel_size=3, stride=1, padding=1)
        
        self.relu1    = nn.ReLU(inplace=True)
        
        self.maxpool1 = MaxPool2d(kernel_size=2)
        

        self.layer_2  = nn.Conv2d(in_channels=4, out_channels=4, kernel_size=3, stride=1, padding=1)
        
        self.relu2    = nn.ReLU(inplace=True)
        
        self.maxpool2 = MaxPool2d(kernel_size=2)
        
        self.drop_out = nn.Dropout()
        
        
        # out_channels = 4, number of classes = 6
        
        # image width = 120, image height = 120 after two maxpooling 120 -> 60 -> 30
        
        self.fc1 = nn.Linear(4 * 30 * 30, 6)
        
    # Defining the forward pass
    def forward(self, x):
        
        out = self.layer_1(x)
        
        out = self.relu1(out)
        
        out = self.maxpool1(out)
        
        
        out = self.layer_2(out)
        
        out = self.relu2(out)
        
        out = self.maxpool2(out)
        
        
        out = out.reshape(out.size(0), -1)
        
        out = self.drop_out(out)
        
        out = self.fc1(out)
        
        return out
    
# Define Model

model_1 = ConvNet_1()

print(model_1)
# Out:
# ConvNet_1(
#   (layer_1): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu1): ReLU(inplace=True)
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (layer_2): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu2): ReLU(inplace=True)
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (drop_out): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=3600, out_features=6, bias=True)
# )

# %%
# Define Criterion

criterion = nn.CrossEntropyLoss()

# Define Optimizer

optimizer = optim.SGD(model_1.parameters(), lr=0.001, momentum=0.9)

# %%
# Whether to train on a gpu and Number of gpus

if cuda.is_available(): 
    
    print(f'{cuda.device_count()} number of gpus are detected and available.')
    
else:
        
    print(f'Train on gpu is not available')
# Out:
# Train on gpu is not available

# %% [markdown]
# Model

# %%
if torch.cuda.is_available():
    
    MODEL = model_1.cuda()
    CRITERION = criterion.cuda()
    print("cuda")
    
else:
    
    MODEL = model_1
    CRITERION = criterion
    print("cpu")

# Train the model

total_step = len(train_data_loader)
loss_list = []
acc_list = []

num_epochs = 5

class_list = ['M','N', 'Q', 'S', 'V', 'F']

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

all_con_mat = torch.zeros([num_epochs, 6, 6], dtype=torch.int32, device=device)

for epoch in range(num_epochs):
    f1_score_list=[0,0,0,0,0,0]

    precision_list=[0,0,0,0,0,0]

    recall_list=[0,0,0,0,0,0]
    
    delta = 0.0000000000001 
    
    # define empty tensor 5*5 beginning of every epoch
    # tensor [row,column]
    con_mat = torch.zeros([6, 6], dtype=torch.int32, device=device)
    
    for i, data in enumerate(train_data_loader):
        
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        
        # optimization
        optimizer.zero_grad()
        
        # Forward to get output
        outputs = MODEL(inputs)
        # Calculate Loss
        loss = CRITERION(outputs, labels)
        # Backward propagation
        loss.backward()
        # Updating parameters
        optimizer.step()
        
        # Store loss
        loss_list.append(loss.item())
    
        # Calculate labels size
        total = labels.size(0)
        
        # Outputs.data has dimension batch size * 5
        # torch.max returns the max value of elements(_) and their indices(predicted) in the tensor array
        _, predicted = torch.max(outputs.data, 1)
        
        # Calculate total number of correct labels 
        correct = (predicted == labels).sum().item()
        
        # Store accuracy
        acc_list.append(correct / total)
        
        for element in range(total):
            
            # con_mat[row,column]
            # con_mat[predictions, actual]
            con_mat[predicted[element].item()-1][labels[element].item()-1] += 1

        if (i + 1) % 300 == 0:                             # every 300 mini-batches...
            
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
                  
                  .format(epoch + 1, num_epochs, i + 1, total_step, loss.item(),
                          (correct / total) * 100))
    print(con_mat)
            
    all_con_mat[epoch] = con_mat
    
    # Print Confusion Matrix
    
    for i in range(torch.sum(con_mat, dim=0).size(0)): 
    
        recall_list[i] = con_mat[i][i].item()/(torch.sum(con_mat, dim=0)[i].item()+delta)
    
        precision_list[i] = con_mat[i][i].item()/(torch.sum(con_mat, dim=1)[i].item()+delta)
    
        f1_score_list[i] = 2 * precision_list[i]*recall_list[i]/(precision_list[i]+recall_list[i]+delta)
        
    
        print('class name: {}, total number of class: {:>6}, Correctly predicted: {:>6}, Recall: {:.2f}%, Precision: {:.2f}%, F1-Score: {:.2f}%'
          
                  .format(class_list[i],
                          torch.sum(con_mat, dim=0)[i].item(),
                          con_mat[i][i].item(), 
                          recall_list[i],
                          precision_list[i],
                          f1_score_list[i]
                         ))
        
print('Finished Training')

plt.plot(loss_list);
plt.show();

plt.plot(acc_list);
plt.show();
# Out:
# cpu
# Epoch [1/5], Step [300/3100], Loss: 1.1463, Accuracy: 62.50%
# Epoch [1/5], Step [600/3100], Loss: 0.3015, Accuracy: 90.62%
# Epoch [1/5], Step [900/3100], Loss: 0.1373, Accuracy: 96.88%
# Epoch [1/5], Step [1200/3100], Loss: 0.0633, Accuracy: 96.88%
# Epoch [1/5], Step [1500/3100], Loss: 0.0610, Accuracy: 100.00%
# Epoch [1/5], Step [1800/3100], Loss: 0.1169, Accuracy: 96.88%
# Epoch [1/5], Step [2100/3100], Loss: 0.2651, Accuracy: 93.75%
# Epoch [1/5], Step [2400/3100], Loss: 0.0278, Accuracy: 100.00%
# Epoch [1/5], Step [2700/3100], Loss: 0.0192, Accuracy: 100.00%
# Epoch [1/5], Step [3000/3100], Loss: 0.0498, Accuracy: 100.00%
# tensor([[ 7014,     6,     0,    97,    65,   116],
#         [ 1212, 75344,  1787,   767,  1809,   124],
#         [    5,   132,  4641,     3,    61,     0],
#         [   46,    16,     0,  1126,   145,    18],
#         [   97,   207,     2,   209,  3657,    46],
#         [   31,     4,     1,    21,    52,   338]], dtype=torch.int32)
# class name: M, total number of class:   8405, Correctly predicted:   7014, Recall: 0.83%, Precision: 0.96%, F1-Score: 0.89%
# class name: N, total number of class:  75709, Correctly predicted:  75344, Recall: 1.00%, Precision: 0.93%, F1-Score: 0.96%
# class name: Q, total number of class:   6431, Correctly predicted:   4641, Recall: 0.72%, Precision: 0.96%, F1-Score: 0.82%
# class name: S, total number of class:   2223, Correctly predicted:   1126, Recall: 0.51%, Precision: 0.83%, F1-Score: 0.63%
# class name: V, total number of class:   5789, Correctly predicted:   3657, Recall: 0.63%, Precision: 0.87%, F1-Score: 0.73%
# class name: F, total number of class:    642, Correctly predicted:    338, Recall: 0.53%, Precision: 0.76%, F1-Score: 0.62%
# Epoch [2/5], Step [300/3100], Loss: 0.1210, Accuracy: 96.88%
# Epoch [2/5], Step [600/3100], Loss: 0.2067, Accuracy: 93.75%
# Epoch [2/5], Step [900/3100], Loss: 0.0599, Accuracy: 96.88%
# Epoch [2/5], Step [1200/3100], Loss: 0.0053, Accuracy: 100.00%
# Epoch [2/5], Step [1500/3100], Loss: 0.0084, Accuracy: 100.00%
# Epoch [2/5], Step [1800/3100], Loss: 0.0035, Accuracy: 100.00%
# Epoch [2/5], Step [2100/3100], Loss: 0.0218, Accuracy: 100.00%
# Epoch [2/5], Step [2400/3100], Loss: 0.0054, Accuracy: 100.00%
# Epoch [2/5], Step [2700/3100], Loss: 0.0038, Accuracy: 100.00%
# Epoch [2/5], Step [3000/3100], Loss: 0.0119, Accuracy: 100.00%
# tensor([[ 8320,     0,     0,    21,    10,    72],
#         [    0, 75630,    37,    45,   153,     1],
#         [    0,    32,  6394,     0,     0,     0],
#         [   19,     4,     0,  1807,   271,    19],
#         [   25,    43,     0,   329,  5315,    48],
#         [   41,     0,     0,    21,    40,   502]], dtype=torch.int32)
# class name: M, total number of class:   8405, Correctly predicted:   8320, Recall: 0.99%, Precision: 0.99%, F1-Score: 0.99%
# class name: N, total number of class:  75709, Correctly predicted:  75630, Recall: 1.00%, Precision: 1.00%, F1-Score: 1.00%
# class name: Q, total number of class:   6431, Correctly predicted:   6394, Recall: 0.99%, Precision: 1.00%, F1-Score: 0.99%
# class name: S, total number of class:   2223, Correctly predicted:   1807, Recall: 0.81%, Precision: 0.85%, F1-Score: 0.83%
# class name: V, total number of class:   5789, Correctly predicted:   5315, Recall: 0.92%, Precision: 0.92%, F1-Score: 0.92%
# class name: F, total number of class:    642, Correctly predicted:    502, Recall: 0.78%, Precision: 0.83%, F1-Score: 0.81%
# Epoch [3/5], Step [300/3100], Loss: 0.0045, Accuracy: 100.00%
# Epoch [3/5], Step [600/3100], Loss: 0.0070, Accuracy: 100.00%
# Epoch [3/5], Step [900/3100], Loss: 0.0035, Accuracy: 100.00%
# Epoch [3/5], Step [1200/3100], Loss: 0.0088, Accuracy: 100.00%
# Epoch [3/5], Step [1500/3100], Loss: 0.0499, Accuracy: 96.88%
# Epoch [3/5], Step [1800/3100], Loss: 0.0196, Accuracy: 100.00%
# Epoch [3/5], Step [2100/3100], Loss: 0.0057, Accuracy: 100.00%
# Epoch [3/5], Step [2400/3100], Loss: 0.0018, Accuracy: 100.00%
# Epoch [3/5], Step [2700/3100], Loss: 0.3970, Accuracy: 93.75%
# Epoch [3/5], Step [3000/3100], Loss: 0.0074, Accuracy: 100.00%
# tensor([[ 8341,     0,     0,     8,    13,    74],
#         [    0, 75667,    26,    15,    51,     0],
#         [    0,    27,  6405,     1,     0,     0],
#         [    8,     0,     0,  1876,   216,    11],
#         [   16,    15,     0,   310,  5483,    32],
#         [   40,     0,     0,    13,    26,   525]], dtype=torch.int32)
# class name: M, total number of class:   8405, Correctly predicted:   8341, Recall: 0.99%, Precision: 0.99%, F1-Score: 0.99%
# class name: N, total number of class:  75709, Correctly predicted:  75667, Recall: 1.00%, Precision: 1.00%, F1-Score: 1.00%
# class name: Q, total number of class:   6431, Correctly predicted:   6405, Recall: 1.00%, Precision: 1.00%, F1-Score: 1.00%
# class name: S, total number of class:   2223, Correctly predicted:   1876, Recall: 0.84%, Precision: 0.89%, F1-Score: 0.87%
# class name: V, total number of class:   5789, Correctly predicted:   5483, Recall: 0.95%, Precision: 0.94%, F1-Score: 0.94%
# class name: F, total number of class:    642, Correctly predicted:    525, Recall: 0.82%, Precision: 0.87%, F1-Score: 0.84%
# Epoch [4/5], Step [300/3100], Loss: 0.0048, Accuracy: 100.00%
# Epoch [4/5], Step [600/3100], Loss: 0.0060, Accuracy: 100.00%
# Epoch [4/5], Step [900/3100], Loss: 0.0150, Accuracy: 100.00%
# Epoch [4/5], Step [1200/3100], Loss: 0.0100, Accuracy: 100.00%
# Epoch [4/5], Step [1500/3100], Loss: 0.0136, Accuracy: 100.00%
# Epoch [4/5], Step [1800/3100], Loss: 0.0575, Accuracy: 96.88%
# Epoch [4/5], Step [2100/3100], Loss: 0.0187, Accuracy: 100.00%
# Epoch [4/5], Step [2400/3100], Loss: 0.0006, Accuracy: 100.00%
# Epoch [4/5], Step [2700/3100], Loss: 0.0017, Accuracy: 100.00%
# Epoch [4/5], Step [3000/3100], Loss: 0.0023, Accuracy: 100.00%
# tensor([[ 8348,     0,     0,    13,     3,    54],
#         [    0, 75678,    26,     6,    23,     0],
#         [    0,    24,  6405,     0,     0,     0],
#         [    6,     0,     0,  1915,   239,    14],
#         [    9,     7,     0,   277,  5502,    28],
#         [   42,     0,     0,    12,    22,   546]], dtype=torch.int32)
# class name: M, total number of class:   8405, Correctly predicted:   8348, Recall: 0.99%, Precision: 0.99%, F1-Score: 0.99%
# class name: N, total number of class:  75709, Correctly predicted:  75678, Recall: 1.00%, Precision: 1.00%, F1-Score: 1.00%
# class name: Q, total number of class:   6431, Correctly predicted:   6405, Recall: 1.00%, Precision: 1.00%, F1-Score: 1.00%
# class name: S, total number of class:   2223, Correctly predicted:   1915, Recall: 0.86%, Precision: 0.88%, F1-Score: 0.87%
# class name: V, total number of class:   5789, Correctly predicted:   5502, Recall: 0.95%, Precision: 0.94%, F1-Score: 0.95%
# class name: F, total number of class:    642, Correctly predicted:    546, Recall: 0.85%, Precision: 0.88%, F1-Score: 0.86%
# Epoch [5/5], Step [300/3100], Loss: 0.0016, Accuracy: 100.00%
# Epoch [5/5], Step [600/3100], Loss: 0.0776, Accuracy: 96.88%
# Epoch [5/5], Step [900/3100], Loss: 0.0018, Accuracy: 100.00%
# Epoch [5/5], Step [1200/3100], Loss: 0.0015, Accuracy: 100.00%
# Epoch [5/5], Step [1500/3100], Loss: 0.0013, Accuracy: 100.00%
# Epoch [5/5], Step [1800/3100], Loss: 0.0250, Accuracy: 96.88%
# Epoch [5/5], Step [2100/3100], Loss: 0.0018, Accuracy: 100.00%
# Epoch [5/5], Step [2400/3100], Loss: 0.0026, Accuracy: 100.00%
# Epoch [5/5], Step [2700/3100], Loss: 0.0032, Accuracy: 100.00%
# Epoch [5/5], Step [3000/3100], Loss: 0.0020, Accuracy: 100.00%
# tensor([[ 8352,     0,     0,    10,     6,    63],
#         [    0, 75682,    21,     7,    19,     0],
#         [    0,    22,  6410,     1,     0,     0],
#         [    5,     1,     0,  1928,   226,    10],
#         [    4,     4,     0,   271,  5524,    24],
#         [   44,     0,     0,     6,    14,   545]], dtype=torch.int32)
# class name: M, total number of class:   8405, Correctly predicted:   8352, Recall: 0.99%, Precision: 0.99%, F1-Score: 0.99%
# class name: N, total number of class:  75709, Correctly predicted:  75682, Recall: 1.00%, Precision: 1.00%, F1-Score: 1.00%
# class name: Q, total number of class:   6431, Correctly predicted:   6410, Recall: 1.00%, Precision: 1.00%, F1-Score: 1.00%
# class name: S, total number of class:   2223, Correctly predicted:   1928, Recall: 0.87%, Precision: 0.89%, F1-Score: 0.88%
# class name: V, total number of class:   5789, Correctly predicted:   5524, Recall: 0.95%, Precision: 0.95%, F1-Score: 0.95%
# class name: F, total number of class:    642, Correctly predicted:    545, Recall: 0.85%, Precision: 0.89%, F1-Score: 0.87%
# Finished Training

# %%
all_con_mat
# Out:
# tensor([[[ 7014,     6,     0,    97,    65,   116],
#          [ 1212, 75344,  1787,   767,  1809,   124],
#          [    5,   132,  4641,     3,    61,     0],
#          [   46,    16,     0,  1126,   145,    18],
#          [   97,   207,     2,   209,  3657,    46],
#          [   31,     4,     1,    21,    52,   338]],
#
#         [[ 8320,     0,     0,    21,    10,    72],
#          [    0, 75630,    37,    45,   153,     1],
#          [    0,    32,  6394,     0,     0,     0],
#          [   19,     4,     0,  1807,   271,    19],
#          [   25,    43,     0,   329,  5315,    48],
#          [   41,     0,     0,    21,    40,   502]],
#
#         [[ 8341,     0,     0,     8,    13,    74],
#          [    0, 75667,    26,    15,    51,     0],
#          [    0,    27,  6405,     1,     0,     0],
#          [    8,     0,     0,  1876,   216,    11],
#          [   16,    15,     0,   310,  5483,    32],
#          [   40,     0,     0,    13,    26,   525]],
#
#         [[ 8348,     0,     0,    13,     3,    54],
#          [    0, 75678,    26,     6,    23,     0],
#          [    0,    24,  6405,     0,     0,     0],
#          [    6,     0,     0,  1915,   239,    14],
#          [    9,     7,     0,   277,  5502,    28],
#          [   42,     0,     0,    12,    22,   546]],
#
#         [[ 8352,     0,     0,    10,     6,    63],
#          [    0, 75682,    21,     7,    19,     0],
#          [    0,    22,  6410,     1,     0,     0],
#          [    5,     1,     0,  1928,   226,    10],
#          [    4,     4,     0,   271,  5524,    24],
#          [   44,     0,     0,     6,    14,   545]]], dtype=torch.int32)

# %% [markdown]
# Check Trained 1. Model on the Test Data

# %%
#evaluate on the test
confusion_mat = torch.zeros([6, 6], dtype=torch.int32, device=device)

with torch.no_grad():
    
    for data in test_data_loader:
        
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        
        outputs = MODEL(inputs)
        
        _, predicted = torch.max(outputs.data, 1)
        
        total = labels.size(0)
        
        # Calculate total number of correct labels 
        correct = (predicted == labels).sum().item()
        
        for element in range(total):
            
            # confusion_mat[row,column]
            # confusion_mat[predictions, actual]
            confusion_mat[predicted[element].item()-1][labels[element].item()-1] += 1

    print(confusion_mat)
# Out:
# tensor([[ 2098,     0,     0,     2,     2,    45],
#         [    0, 18924,     4,     1,     2,     0],
#         [    0,     1,  1604,     0,     0,     0],
#         [    2,     1,     0,   500,    89,     1],
#         [    0,     0,     0,    51,  1353,     5],
#         [    1,     0,     0,     2,     1,   110]], dtype=torch.int32)

# %%
class_list = ['M','N', 'Q', 'S', 'V', 'F']

f1_score_list=[0,0,0,0,0,0]

precision_list=[0,0,0,0,0,0]

recall_list=[0,0,0,0,0,0]
    
delta = 0.0000000000001 


for i in range(torch.sum(confusion_mat, dim=0).size(0)): 
    
        recall_list[i] = confusion_mat[i][i].item()/(torch.sum(confusion_mat, dim=0)[i].item()+delta)
    
        precision_list[i] = confusion_mat[i][i].item()/(torch.sum(confusion_mat, dim=1)[i].item()+delta)
    
        f1_score_list[i] = 2 * precision_list[i]*recall_list[i]/(precision_list[i]+recall_list[i]+delta)
        
        print('class name: {}, total number of class: {:>6}, Correctly predicted: {:>6}, Recall: {:.2f}%, Precision: {:.2f}%, F1-Score: {:.2f}%'
          
                  .format(class_list[i],
                          torch.sum(confusion_mat, dim=0)[i].item(),
                          confusion_mat[i][i].item(), 
                          recall_list[i],
                          precision_list[i],
                          f1_score_list[i]
                         ))
# Out:
# class name: M, total number of class:   2101, Correctly predicted:   2098, Recall: 1.00%, Precision: 0.98%, F1-Score: 0.99%
# class name: N, total number of class:  18926, Correctly predicted:  18924, Recall: 1.00%, Precision: 1.00%, F1-Score: 1.00%
# class name: Q, total number of class:   1608, Correctly predicted:   1604, Recall: 1.00%, Precision: 1.00%, F1-Score: 1.00%
# class name: S, total number of class:    556, Correctly predicted:    500, Recall: 0.90%, Precision: 0.84%, F1-Score: 0.87%
# class name: V, total number of class:   1447, Correctly predicted:   1353, Recall: 0.94%, Precision: 0.96%, F1-Score: 0.95%
# class name: F, total number of class:    161, Correctly predicted:    110, Recall: 0.68%, Precision: 0.96%, F1-Score: 0.80%

# %%
#save model
model_path = "ECG_model.pth"
torch.save(model_1.state_dict(), model_path)

# %%
loaded_model = ConvNet_1()
loaded_model.load_state_dict(torch.load(model_path))
loaded_model.to(device)
# Out:
# <All keys matched successfully>
# ConvNet_1(
#   (layer_1): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu1): ReLU(inplace=True)
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (layer_2): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu2): ReLU(inplace=True)
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (drop_out): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=3600, out_features=6, bias=True)
# )

# %%
#test the loaded model
def test_model(model, test_data_loader, criterion):
    # Code to test the model goes here
    # For example:
    model.eval()  # Set the model to evaluation mode
    total_loss = 0.0
    correct_predictions = 0
    total_samples = 0

    with torch.no_grad():
        for inputs, labels in test_data_loader:
            # Forward pass
            outputs = model(inputs)
            
            # Calculate loss
            loss = criterion(outputs, labels)
            total_loss += loss.item()

            # Count correct predictions
            _, predicted = torch.max(outputs, 1)
            correct_predictions += (predicted == labels).sum().item()

            total_samples += labels.size(0)

    accuracy = correct_predictions / total_samples
    average_loss = total_loss / len(test_data_loader)

    print(f'Test Accuracy: {accuracy:.4f}, Average Loss: {average_loss:.4f}')

# Now you can call the test_model function
test_model(loaded_model, test_data_loader, criterion)
# Out:
# Test Accuracy: 0.9948, Average Loss: 0.0184

# %%
# extract tp,tn. fp. fn
# Calculate sensitivity and specificity for each class
sensitivity_list = []
specificity_list = []

for i in range(confusion_mat.shape[0]):
    TP = confusion_mat[i, i]
    FN = sum(confusion_mat[i, :]) - TP
    FP = sum(confusion_mat[:, i]) - TP
    TN = sum(sum(confusion_mat)) - TP - FN - FP
    
    sensitivity = TP / (TP + FN + 1e-10)  # Adding a small constant to avoid division by zero
    specificity = TN / (TN + FP + 1e-10)  # Adding a small constant to avoid division by zero
    
    sensitivity_list.append(sensitivity)
    specificity_list.append(specificity)

    print(f'Class {class_list[i]}: Sensitivity = {sensitivity:.4f}, Specificity = {specificity:.4f}')

# Calculate the average sensitivity and specificity across all classes
average_sensitivity = sum(sensitivity_list) / len(sensitivity_list)
average_specificity = sum(specificity_list) / len(specificity_list)

print(f'Average Sensitivity = {average_sensitivity:.4f}, Average Specificity = {average_specificity:.4f}')
# Out:
# Class M: Sensitivity = 0.9772, Specificity = 0.9999
# Class N: Sensitivity = 0.9996, Specificity = 0.9997
# Class Q: Sensitivity = 0.9994, Specificity = 0.9998
# Class S: Sensitivity = 0.8432, Specificity = 0.9977
# Class V: Sensitivity = 0.9603, Specificity = 0.9960
# Class F: Sensitivity = 0.9649, Specificity = 0.9979
# Average Sensitivity = 0.9574, Average Specificity = 0.9985

# %%
# 1. Confusion Matrix Analysis
def plot_confusion_matrix(confusion_mat, class_names):
    df_cm = pd.DataFrame(confusion_mat, index=class_names, columns=class_names)
    plt.figure(figsize=(8, 6))
    sns.heatmap(df_cm, annot=True, fmt="d", cmap="Blues")
    plt.title("Confusion Matrix")
    plt.xlabel("Actual")
    plt.ylabel("Predicted")
    plt.show()

# 2. Visualization
def plot_curves(loss_list, acc_list):
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(loss_list, label='Training Loss')
    plt.title('Training Loss Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(acc_list, label='Training Accuracy')
    plt.title('Training Accuracy Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()


# Plot confusion matrix
plot_confusion_matrix(confusion_mat, class_list)

# Plot training curves
plot_curves(loss_list, acc_list)

# %%
# Plotting for sensitivity & specifity
fig, ax = plt.subplots(figsize=(10, 6))

bar_width = 0.35
index = np.arange(len(class_list))

bar1 = ax.bar(index, sensitivity_list, bar_width, label='Sensitivity', color='b')
bar2 = ax.bar(index + bar_width, specificity_list, bar_width, label='Specificity', color='r')

ax.set_xlabel('Classes')
ax.set_ylabel('Metrics')
ax.set_title('Sensitivity and Specificity for each Class')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(class_list)
ax.legend()

plt.show()
# Out:
# Text(0.5, 0, 'Classes')
# Text(0, 0.5, 'Metrics')
# Text(0.5, 1.0, 'Sensitivity and Specificity for each Class')
# [<matplotlib.axis.XTick at 0x2ab82603490>,
#  <matplotlib.axis.XTick at 0x2ab82603460>,
#  <matplotlib.axis.XTick at 0x2ab825d58b0>,
#  <matplotlib.axis.XTick at 0x2ab8269c460>,
#  <matplotlib.axis.XTick at 0x2ab8269cbb0>,
#  <matplotlib.axis.XTick at 0x2ab82694310>]
# [Text(0.175, 0, 'M'),
#  Text(1.175, 0, 'N'),
#  Text(2.175, 0, 'Q'),
#  Text(3.175, 0, 'S'),
#  Text(4.175, 0, 'V'),
#  Text(5.175, 0, 'F')]
